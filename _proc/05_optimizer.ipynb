# %% [raw]
# ---
# output-file: optimizer.html
# title: Optimizer
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(optimize_plan)
# Out:
# ```python
#
# def optimize_plan(
#     plan:LogicalPlan
# )->OptimizationResult:
#
#
# ```
#
# *Optimize a LogicalPlan with default pass pipeline.*

# %%
#| echo: false
#| output: asis
show_doc(PlanOptimizer)
# Out:
# ```python
#
# def PlanOptimizer(
#     args:VAR_POSITIONAL, kwargs:VAR_KEYWORD
# ):
#
#
# ```
#
# *Rule-based optimizer for LogicalPlan trees.*
#
# This starts with conservative semantic-preserving rewrites.

# %%
#| echo: false
#| output: asis
show_doc(OptimizationResult)
# Out:
# ```python
#
# def OptimizationResult(
#     plan:LogicalPlan, trace:List
# )->None:
#
#
# ```
#
# *Optimizer output containing a potentially rewritten plan and pass trace.*
