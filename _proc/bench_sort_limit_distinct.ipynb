# %% [raw]
# ---
# description: Benchmark for Phase 4 MXFrame operations using Mojo sort_indices and
#   unique_mask kernels.
# output-file: bench_sort_limit_distinct.html
# title: 'Phase 4 Benchmark: Sort / Limit / Distinct'
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## 1) Synthetic data

# %% [markdown]
# ## 2) Query implementations

# %% [markdown]
# ## 3) Benchmark
